# %% [markdown]
# ## 載入所需套件

# %%
import warnings
warnings.filterwarnings('ignore')

import yfinance as yf
import pyfolio as pf
# %matplotlib inline

# %% [markdown]
# ## 從Yahoo finance下載2330的股價資料

# %%
data = yf.Ticker('2330.TW')
history = data.history('max')
history.index = history.index.tz_localize('utc')

# %%
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5547 entries, 2000-01-04 00:00:00+00:00 to 2022-03-21 00:00:00+00:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          5547 non-null   float64
#  1   High          5547 non-null   float64
#  2   Low           5547 non-null   float64
#  3   Close         5547 non-null   float64
#  4   Volume        5547 non-null   int64
#  5   Dividends     5547 non-null   float64
#  6   Stock Splits  5547 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 346.7 KB

# %%
returns = history.Close.pct_change()

# %%
pf.create_returns_tear_sheet(returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2000-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-21</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>264</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>13.513%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1527.922%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>31.136%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.20</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-67.957%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.14</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.853%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>67.96</td>
#       <td>2000-02-11</td>
#       <td>2002-10-08</td>
#       <td>2010-11-03</td>
#       <td>2799</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>27.63</td>
#       <td>2020-01-14</td>
#       <td>2020-03-19</td>
#       <td>2020-07-08</td>
#       <td>127</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>23.20</td>
#       <td>2015-02-25</td>
#       <td>2015-08-24</td>
#       <td>2016-02-18</td>
#       <td>257</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21.51</td>
#       <td>2018-09-27</td>
#       <td>2019-01-04</td>
#       <td>2019-04-22</td>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18.39</td>
#       <td>2021-01-21</td>
#       <td>2021-05-13</td>
#       <td>2022-01-14</td>
#       <td>257</td>
#     </tr>
#   </tbody>
# </table>
