# %% [markdown]
# ## 載入所需套件

# %%
import warnings
warnings.filterwarnings('ignore')

import yfinance as yf
import pyfolio as pf
# %matplotlib inline

# %% [markdown]
# ## 從Yahoo finance下載TLT的股價資料

# %%
data = yf.Ticker('TLT')
history = data.history('max')
history.index = history.index.tz_localize('utc')

# %%
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4946 entries, 2002-07-30 00:00:00+00:00 to 2022-03-21 00:00:00+00:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          4946 non-null   float64
#  1   High          4946 non-null   float64
#  2   Low           4946 non-null   float64
#  3   Close         4946 non-null   float64
#  4   Volume        4946 non-null   int64
#  5   Dividends     4946 non-null   float64
#  6   Stock Splits  4946 non-null   int64
# dtypes: float64(5), int64(2)
# memory usage: 309.1 KB

# %%
returns = history.Close.pct_change()

# %%
pf.create_returns_tear_sheet(returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2002-07-30</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-21</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>235</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>5.979%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>212.573%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.944%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.49</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.22</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-26.585%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.73%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26.59</td>
#       <td>2008-12-30</td>
#       <td>2009-06-10</td>
#       <td>2011-08-18</td>
#       <td>688</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>21.53</td>
#       <td>2020-08-04</td>
#       <td>2022-03-15</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20.66</td>
#       <td>2012-07-25</td>
#       <td>2013-08-21</td>
#       <td>2014-12-10</td>
#       <td>621</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.88</td>
#       <td>2016-07-08</td>
#       <td>2016-12-14</td>
#       <td>2019-07-02</td>
#       <td>778</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.81</td>
#       <td>2015-01-30</td>
#       <td>2015-06-26</td>
#       <td>2016-06-09</td>
#       <td>355</td>
#     </tr>
#   </tbody>
# </table>
